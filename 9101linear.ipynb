# %%
# 导入必要的库
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
rawdataset=np.load('new_feature_matrix.npy')

# %%
np.shape(rawdataset)
# Out:
# (90, 172, 5)

# %%
dataset = rawdataset.reshape(-1, rawdataset.shape[2])

# %%
np.shape(dataset)
# Out:
# (15480, 5)

# %%
X = dataset[:, 0:4]
y = dataset[:, 4]

# %%
from sklearn.model_selection import train_test_split

# %%
# 将数据分为训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Fit the model on the training data
model.fit(X_train, y_train)

# Predict on the test data
predictions = model.predict(X_test)

# Prepare for plotting - this part needs to be checked and possibly corrected
# We will plot only the first feature against the target for demonstration purposes
plt.scatter(X_test[:, 0], y_test, color='red')  # Plotting test data points
plt.plot(X_test[:, 0], predictions, color='blue', linewidth=2)  # Plotting the regression line

# Add title and labels to the plot
plt.title('Linear Regression')
plt.xlabel('x')
plt.ylabel('Target')

# Display the plot
plt.show()
